# %%
import pandas as pd
import numpy as np
import seaborn as sns 
import matplotlib.pyplot as plt
# %matplotlib inline     
sns.set(color_codes=True)

# %%
df=pd.read_csv("Online Retail.csv")

# %%
df.head()
# Out:
#   InvoiceNo StockCode                          Description  Quantity  \
# 0    536365    85123A   WHITE HANGING HEART T-LIGHT HOLDER         6
# 1    536365     71053                  WHITE METAL LANTERN         6
# 2    536365    84406B       CREAM CUPID HEARTS COAT HANGER         8
# 3    536365    84029G  KNITTED UNION FLAG HOT WATER BOTTLE         6
# 4    536365    84029E       RED WOOLLY HOTTIE WHITE HEART.         6
#
#      InvoiceDate  UnitPrice  CustomerID         Country
# 0  01-12-10 8:26       2.55     17850.0  United Kingdom
# 1  01-12-10 8:26       3.39     17850.0  United Kingdom
# 2  01-12-10 8:26       2.75     17850.0  United Kingdom
# 3  01-12-10 8:26       3.39     17850.0  United Kingdom
# 4  01-12-10 8:26       3.39     17850.0  United Kingdom

# %%
df.tail()
# Out:
#        InvoiceNo StockCode                      Description  Quantity  \
# 541904    581587     22613      PACK OF 20 SPACEBOY NAPKINS        12
# 541905    581587     22899     CHILDREN'S APRON DOLLY GIRL          6
# 541906    581587     23254    CHILDRENS CUTLERY DOLLY GIRL          4
# 541907    581587     23255  CHILDRENS CUTLERY CIRCUS PARADE         4
# 541908    581587     22138    BAKING SET 9 PIECE RETROSPOT          3
#
#            InvoiceDate  UnitPrice  CustomerID Country
# 541904  09-12-11 12:50       0.85     12680.0  France
# 541905  09-12-11 12:50       2.10     12680.0  France
# 541906  09-12-11 12:50       4.15     12680.0  France
# 541907  09-12-11 12:50       4.15     12680.0  France
# 541908  09-12-11 12:50       4.95     12680.0  France

# %%
df.shape
# Out:
# (541909, 8)

# %%
df.dtypes
# Out:
# InvoiceNo       object
# StockCode       object
# Description     object
# Quantity         int64
# InvoiceDate     object
# UnitPrice      float64
# CustomerID     float64
# Country         object
# dtype: object

# %%
df.sample()
# Out:
#        InvoiceNo StockCode           Description  Quantity     InvoiceDate  \
# 222605    556435     22624  IVORY KITCHEN SCALES         2  10-06-11 14:08
#
#         UnitPrice  CustomerID         Country
# 222605        8.5     14895.0  United Kingdom

# %%
df.sample(10)
# Out:
#        InvoiceNo StockCode                          Description  Quantity  \
# 339130    566581     22297            HEART IVORY TRELLIS SMALL        24
# 365231    568702     84077    WORLD WAR 2 GLIDERS ASSTD DESIGNS        40
# 451875    575298     23216            LAUREL HEART ANTIQUE GOLD         2
# 535969    581217     82580                  BATHROOM METAL SIGN         2
# 387070    570258     23170             REGENCY TEA PLATE ROSES          1
# 500623    578790     23343         JUMBO BAG VINTAGE CHRISTMAS          2
# 299801    563170     22773  GREEN DRAWER KNOB ACRYLIC EDWARDIAN        12
# 188871    553067     23148    MINIATURE ANTIQUE ROSE HOOK IVORY        12
# 459982    575890     22178      VICTORIAN GLASS HANGING T-LIGHT        12
# 120057    546644    35810A         ENAMEL PINK COFFEE CONTAINER        24
#
#            InvoiceDate  UnitPrice  CustomerID         Country
# 339130  13-09-11 13:47       1.25     16081.0  United Kingdom
# ...

# %%
df.sample(100)
# Out:
#        InvoiceNo StockCode                          Description  Quantity  \
# 471328    576633     23483    HANGING  BUTTERFLY T-LIGHT HOLDER        72
# 398741    571257     21993           FLORAL FOLK STATIONERY SET         1
# 331211    565995     21922    UNION STRIPE WITH FRINGE  HAMMOCK         1
# 540048    581456     22964   3 PIECE SPACEBOY COOKIE CUTTER SET         2
# 320102    564962     22350                ILLUSTRATED CAT BOWL          1
# ...          ...       ...                                  ...       ...
# 116698    546303      POST                              POSTAGE         1
# 500196    578746     22631             CIRCUS PARADE LUNCH BOX          2
# 429948    573576    47593B                SCOTTIE DOGS BABY BIB         1
# 471629    576645     22596  CHRISTMAS STAR WISH LIST CHALKBOARD        12
# 20560     538065     21790                   VINTAGE SNAP CARDS        12
#
#            InvoiceDate  UnitPrice  CustomerID         Country
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 541909 entries, 0 to 541908
# Data columns (total 8 columns):
#  #   Column       Non-Null Count   Dtype
# ---  ------       --------------   -----
#  0   InvoiceNo    541909 non-null  object
#  1   StockCode    541909 non-null  object
#  2   Description  540455 non-null  object
#  3   Quantity     541909 non-null  int64
#  4   InvoiceDate  541909 non-null  object
#  5   UnitPrice    541909 non-null  float64
#  6   CustomerID   406829 non-null  float64
#  7   Country      541909 non-null  object
# dtypes: float64(2), int64(1), object(5)
# memory usage: 33.1+ MB

# %%
df.isnull().sum()
# Out:
# InvoiceNo           0
# StockCode           0
# Description      1454
# Quantity            0
# InvoiceDate         0
# UnitPrice           0
# CustomerID     135080
# Country             0
# dtype: int64

# %%
df.describe
# Out:
# <bound method NDFrame.describe of        InvoiceNo StockCode                          Description  Quantity  \
# 0         536365    85123A   WHITE HANGING HEART T-LIGHT HOLDER         6
# 1         536365     71053                  WHITE METAL LANTERN         6
# 2         536365    84406B       CREAM CUPID HEARTS COAT HANGER         8
# 3         536365    84029G  KNITTED UNION FLAG HOT WATER BOTTLE         6
# 4         536365    84029E       RED WOOLLY HOTTIE WHITE HEART.         6
# ...          ...       ...                                  ...       ...
# 541904    581587     22613          PACK OF 20 SPACEBOY NAPKINS        12
# 541905    581587     22899         CHILDREN'S APRON DOLLY GIRL          6
# 541906    581587     23254        CHILDRENS CUTLERY DOLLY GIRL          4
# 541907    581587     23255      CHILDRENS CUTLERY CIRCUS PARADE         4
# 541908    581587     22138        BAKING SET 9 PIECE RETROSPOT          3
#
# ...

# %%
df.describe(include="all")
# Out:
#        InvoiceNo StockCode                         Description       Quantity  \
# count     541909    541909                              540455  541909.000000
# unique     25900      4070                                4223            NaN
# top       573585    85123A  WHITE HANGING HEART T-LIGHT HOLDER            NaN
# freq        1114      2313                                2369            NaN
# mean         NaN       NaN                                 NaN       9.552250
# std          NaN       NaN                                 NaN     218.081158
# min          NaN       NaN                                 NaN  -80995.000000
# 25%          NaN       NaN                                 NaN       1.000000
# 50%          NaN       NaN                                 NaN       3.000000
# 75%          NaN       NaN                                 NaN      10.000000
# max          NaN       NaN                                 NaN   80995.000000
#
# ...

# %%
duplicate_rows_df = df[df.duplicated()]
print("number of duplicate rows: ", duplicate_rows_df.shape)
# Out:
# number of duplicate rows:  (5268, 8)

# %%
df.count()      # Used to count the number of rows
# Out:
# InvoiceNo      541909
# StockCode      541909
# Description    540455
# Quantity       541909
# InvoiceDate    541909
# UnitPrice      541909
# CustomerID     406829
# Country        541909
# dtype: int64

# %%
df = df.drop_duplicates()
df.head(5)
# Out:
#   InvoiceNo StockCode                          Description  Quantity  \
# 0    536365    85123A   WHITE HANGING HEART T-LIGHT HOLDER         6
# 1    536365     71053                  WHITE METAL LANTERN         6
# 2    536365    84406B       CREAM CUPID HEARTS COAT HANGER         8
# 3    536365    84029G  KNITTED UNION FLAG HOT WATER BOTTLE         6
# 4    536365    84029E       RED WOOLLY HOTTIE WHITE HEART.         6
#
#      InvoiceDate  UnitPrice  CustomerID         Country
# 0  01-12-10 8:26       2.55     17850.0  United Kingdom
# 1  01-12-10 8:26       3.39     17850.0  United Kingdom
# 2  01-12-10 8:26       2.75     17850.0  United Kingdom
# 3  01-12-10 8:26       3.39     17850.0  United Kingdom
# 4  01-12-10 8:26       3.39     17850.0  United Kingdom

# %%
df.count()
# Out:
# InvoiceNo      536641
# StockCode      536641
# Description    535187
# Quantity       536641
# InvoiceDate    536641
# UnitPrice      536641
# CustomerID     401604
# Country        536641
# dtype: int64

# %%
print(df.isnull().sum())
# Out:
# InvoiceNo           0
# StockCode           0
# Description      1454
# Quantity            0
# InvoiceDate         0
# UnitPrice           0
# CustomerID     135037
# Country             0
# dtype: int64

# %%
df = df.dropna()    # Dropping the missing values.
df.count()
# Out:
# InvoiceNo      401604
# StockCode      401604
# Description    401604
# Quantity       401604
# InvoiceDate    401604
# UnitPrice      401604
# CustomerID     401604
# Country        401604
# dtype: int64

# %%
print(df.isnull().sum())   # After dropping the values
# Out:
# InvoiceNo      0
# StockCode      0
# Description    0
# Quantity       0
# InvoiceDate    0
# UnitPrice      0
# CustomerID     0
# Country        0
# dtype: int64

# %%
sns.boxplot(x=df['UnitPrice'])
# Out:
# <Axes: xlabel='UnitPrice'>

# %%
sns.boxplot(x=df['Quantity'])
# Out:
# <Axes: xlabel='Quantity'>

# %%
df.columns
# Out:
# Index(['InvoiceNo', 'StockCode', 'Description', 'Quantity', 'InvoiceDate',
#        'UnitPrice', 'CustomerID', 'Country'],
#       dtype='object')

# %%
df.Description.value_counts().nlargest(40).plot(kind='bar', figsize=(10,5))
plt.title("InvoiceDate")
plt.ylabel('Quantity')
plt.xlabel('UnitPrice');

# %%
df.Description.value_counts().nlargest(40).plot(kind='bar', figsize=(10,5))
plt.title("Invoice Data")
plt.ylabel('UnitPrice')
plt.xlabel('Quantity');

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# Load the dataset
df = pd.read_csv('Online Retail.csv', encoding='ISO-8859-1')

# Select only numeric columns
numeric_df = df.select_dtypes(include=['float64', 'int64'])

# Calculate the correlation matrix
c = numeric_df.corr()

# Customize the figure size
plt.figure(figsize=(10, 5))

# Create the heatmap
sns.heatmap(c, cmap="BrBG", annot=True)

# Display the correlation matrix
print(c)
# Out:
#             Quantity  UnitPrice  CustomerID
# Quantity    1.000000  -0.001235    -0.00360
# UnitPrice  -0.001235   1.000000    -0.00456
# CustomerID -0.003600  -0.004560     1.00000

# %%
fig, ax = plt.subplots(figsize=(10,6))
ax.scatter(df['Quantity'], df['UnitPrice'])
ax.set_xlabel('Quantity')
ax.set_ylabel('UnitPrice')
plt.show()
